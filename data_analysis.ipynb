# %%
import numpy as np
import pandas as pd
from read_data import load_data
df, df_agg = load_data()

# %%
df
# Out:
#        Unnamed: 0     ID        Date               Source  \
# 0               0      0    1/1/2022  5458204279082333846
# 1               1      1    1/1/2022  5458204279082333846
# 2               2      2    1/1/2022  5458204279082333846
# 3               3      3    1/1/2022  5458204279082333846
# 4               4      4    1/1/2022  5458204279082333846
# ...           ...    ...         ...                  ...
# 62576       62576  34839  12/22/2023  1911314253347375714
# 62577       62577  34840  12/22/2023  1911314253347375714
# 62578       62578  34841  12/22/2023  1911314253347375714
# 62579       62579  34842  12/22/2023  1911314253347375714
# 62580       62580  34843  12/22/2023  1911314253347375714
#
#                 Destination   Volume         Value   Revenues  Platform
# 0       -499896596931714151     27.0  3.851957e+05      72.32  Network1
# 1       5279677663854696991  77927.0  1.148725e+09  208733.04  Network1
# ...

# %%
df_agg
# Out:
#                     Source           Destination  Platform   total_vol  \
# 1183  -4312125034382657644   4236239717083668998  Network1  38474265.0
# 5873   5458204279082333846   4236239717083668998  Network1  36399278.0
# 1316  -4448166669477066280   4236239717083668998  Network1  33533609.0
# 4993   4236239717083668998  -4312125034382657644  Network1  28523821.0
# 5037   4236239717083668998   5458204279082333846  Network1  22870042.0
# ...                    ...                   ...       ...         ...
# 5493    520128278214306640   6507827448414474445  Network2         1.0
# 4630    329525002259471666   5780328645265204608  Network2         1.0
# 538   -1952142598191508293    752480581181166200  Network2         1.0
# 2955   -784342624937920273   7029008074767476760  Network1         1.0
# 6225   6558086471840104424  -3176297685568719447  Network2         1.0
#
#          total_val    total_fees
# 1183  1.833807e+11  1.030561e+08
# 5873  1.369811e+11  9.747485e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62581 entries, 0 to 62580
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   62581 non-null  int64
#  1   ID           62581 non-null  int64
#  2   Date         62581 non-null  object
#  3   Source       62581 non-null  object
#  4   Destination  62581 non-null  object
#  5   Volume       62581 non-null  float64
#  6   Value        62581 non-null  float64
#  7   Revenues     62581 non-null  float64
#  8   Platform     62581 non-null  object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 4.3+ MB
